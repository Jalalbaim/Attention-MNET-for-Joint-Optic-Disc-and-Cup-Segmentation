# %% [markdown]
# # Training MNet

# %%
import numpy as np
from keras import backend as K
import scipy
from skimage.measure import label, regionprops
import os
from keras.preprocessing import image
import tensorflow as tf
from keras.optimizers import SGD
from keras.layers import (
    Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, BatchNormalization,
    Activation, Conv2DTranspose, Multiply, Add, AveragePooling2D, Average
)
from keras.models import Model
import random
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ## Utils

# %%
# Define helper functions
def mk_dir(dir_path):
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)
    return dir_path

def return_list(data_path, data_type):
    file_list = [file for file in os.listdir(data_path) if file.lower().endswith(data_type)]
    print(str(len(file_list)))
    return file_list

def train_loader(data_list, data_path, mask_path, input_size):
    for lineIdx in range(len(data_list)):
        temp_txt = data_list[lineIdx]

        train_img = np.asarray(image.load_img(
            os.path.join(data_path, temp_txt),
            target_size=(input_size, input_size, 3))
        ).astype('float32')

        img_mask = np.asarray(image.load_img(
            os.path.join(mask_path, temp_txt),
            target_size=(input_size, input_size, 3))) / 255.0

        img_mask = img_mask.astype('float32')

        yield (train_img, (img_mask, img_mask, img_mask, img_mask, img_mask))


def tf_data_loader(data_list, data_path, mask_path, input_size):
    dataset = tf.data.Dataset.from_generator(
        lambda: train_loader(data_list, data_path, mask_path, input_size),
        output_signature=(
            tf.TensorSpec(shape=(input_size, input_size, 3), dtype=tf.float32),
            tuple([tf.TensorSpec(shape=(input_size, input_size, 3), dtype=tf.float32)] * 5)
        )
    )
    return dataset

# %%
# Training Settings
result_path = mk_dir('/kaggle/working/output_deep_model/')
#pre_model_file = '/kaggle/input/deep-model/deep_model/Model_MNet_REFUGE.h5'
save_model_file = os.path.join(result_path, 'Model_MNet_REFUGE_v2.keras')

root_path = '/kaggle/input/training-data-polar/training_crop/'
train_data_path = root_path + 'data/'
train_mask_path = root_path + 'label/'

val_data_path = root_path + 'val_data/data/'
val_mask_path = root_path + 'val_data/label/'

train_list = return_list(train_data_path, '.png')
val_list = return_list(val_data_path, '.png')
# Out:
# 1400
# 300

# %% [markdown]
# ## Model MNet

# %%
from keras.layers import (
    Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate,
    BatchNormalization, Activation, Conv2DTranspose, Multiply,
    Add, AveragePooling2D, Average, GlobalAveragePooling2D,
    Reshape, Dense
)
from keras.models import Model
import tensorflow as tf


def residual_block(x, filters, block_name):
    """
    A residual block with two convolutional layers and a skip connection.

    Parameters:
    - x: Input tensor.
    - filters: Number of filters for the convolutional layers.
    - block_name: Base name for the layers in this block.

    Returns:
    - Output tensor after applying the residual block.
    """
    # First convolutional layer
    conv = Conv2D(filters, (3, 3), padding='same', name=f'{block_name}_conv1')(x)
    conv = BatchNormalization(name=f'{block_name}_bn1')(conv)
    conv = Activation('relu', name=f'{block_name}_relu1')(conv)

    # Second convolutional layer
    conv = Conv2D(filters, (3, 3), padding='same', name=f'{block_name}_conv2')(conv)
    conv = BatchNormalization(name=f'{block_name}_bn2')(conv)

    # Shortcut connection
    shortcut = Conv2D(filters, (1, 1), padding='same', name=f'{block_name}_shortcut')(x)
    shortcut = BatchNormalization(name=f'{block_name}_shortcut_bn')(shortcut)

    # Adding the shortcut to the main path
    out = Add(name=f'{block_name}_add')([conv, shortcut])
    out = Activation('relu', name=f'{block_name}_relu2')(out)
    return out


def se_block(input_tensor, filters, block_name, ratio=16):
    """
    Squeeze-and-Excitation (SE) block.

    Parameters:
    - input_tensor: Input Keras tensor.
    - filters: Number of filters (channels) of input_tensor.
    - block_name: Base name for the layers in this block.
    - ratio: Reduction ratio for the bottleneck in the SE block.

    Returns:
    - A Keras tensor after applying the SE attention.
    """
    # 1. Squeeze: Global Average Pooling
    se = GlobalAveragePooling2D(name=f'{block_name}_gap')(input_tensor)
    se = Reshape((1, 1, filters), name=f'{block_name}_reshape')(se)

    # 2. Excitation: Two FC layers (Dense). First reduces dimension, then scales back
    reduced_filters = max(filters // ratio, 1)
    se = Dense(reduced_filters, activation='relu', name=f'{block_name}_fc1')(se)
    se = Dense(filters, activation='sigmoid', name=f'{block_name}_fc2')(se)

    # 3. Scale: Multiply the original feature maps by the learned channel weights
    x = Multiply(name=f'{block_name}_scale')([input_tensor, se])
    return x


def attention_gate(x, g, inter_channels, name_prefix):
    """
    Attention Gate with unique naming.

    Parameters:
    - x: Input feature map from the encoder (skip connection).
    - g: Gating signal from the decoder.
    - inter_channels: Number of filters for intermediate computations.
    - name_prefix: Unique prefix for naming the layers.

    Returns:
    - Attention-weighted feature map.
    """
    theta_x = Conv2D(inter_channels, (2, 2), strides=(2, 2), padding='same', name=f'{name_prefix}_theta_x')(x)
    phi_g = Conv2D(inter_channels, (1, 1), padding='same', name=f'{name_prefix}_phi_g')(g)
    add = Add(name=f'{name_prefix}_add')([theta_x, phi_g])
    relu = Activation('relu', name=f'{name_prefix}_relu')(add)
    psi = Conv2D(1, (1, 1), padding='same', name=f'{name_prefix}_psi')(relu)
    sigmoid = Activation('sigmoid', name=f'{name_prefix}_sigmoid')(psi)

    # Upsample back to x's size
    upsampled = UpSampling2D(size=(2, 2), interpolation='bilinear', name=f'{name_prefix}_upsample')(sigmoid)

    # Apply attention coefficients element-wise
    attn_coefficients = Multiply(name=f'{name_prefix}_multiply')([x, upsampled])
    return attn_coefficients


def DeepModel(size_set=800):
    """
    Builds the deep learning model with:
      - Residual connections in the encoder
      - Attention gates
      - SE blocks in the decoder

    Parameters:
    - size_set: The height and width of the input images.

    Returns:
    - A Keras Model instance.
    """
    # ----- Input -----
    img_input = Input(shape=(size_set, size_set, 3), name='input_image')

    # ----- Downscale the input image for skip connections -----
    scale_img_2 = AveragePooling2D(pool_size=(2, 2), name='scale_img_2')(img_input)
    scale_img_3 = AveragePooling2D(pool_size=(2, 2), name='scale_img_3')(scale_img_2)
    scale_img_4 = AveragePooling2D(pool_size=(2, 2), name='scale_img_4')(scale_img_3)

    # ----- Encoder (Residual Blocks) -----
    # Block 1
    conv1 = residual_block(img_input, 32, 'block1')
    pool1 = MaxPooling2D(pool_size=(2, 2), name='pool1')(conv1)

    # Block 2
    input2 = Conv2D(64, (3, 3), padding='same', name='block2_input1')(scale_img_2)
    input2 = BatchNormalization(name='block2_input1_bn')(input2)
    input2 = Activation('relu', name='block2_input1_relu')(input2)
    input2 = concatenate([input2, pool1], axis=3, name='block2_concat')
    conv2 = residual_block(input2, 64, 'block2')
    pool2 = MaxPooling2D(pool_size=(2, 2), name='pool2')(conv2)

    # Block 3
    input3 = Conv2D(128, (3, 3), padding='same', name='block3_input1')(scale_img_3)
    input3 = BatchNormalization(name='block3_input1_bn')(input3)
    input3 = Activation('relu', name='block3_input1_relu')(input3)
    input3 = concatenate([input3, pool2], axis=3, name='block3_concat')
    conv3 = residual_block(input3, 128, 'block3')
    pool3 = MaxPooling2D(pool_size=(2, 2), name='pool3')(conv3)

    # Block 4
    input4 = Conv2D(256, (3, 3), padding='same', name='block4_input1')(scale_img_4)
    input4 = BatchNormalization(name='block4_input1_bn')(input4)
    input4 = Activation('relu', name='block4_input1_relu')(input4)
    input4 = concatenate([input4, pool3], axis=3, name='block4_concat')
    conv4 = residual_block(input4, 256, 'block4')
    pool4 = MaxPooling2D(pool_size=(2, 2), name='pool4')(conv4)

    # Bridge (Block 5)
    conv5 = residual_block(pool4, 512, 'block5')

    # ----- Decoder (Attention + SE blocks) -----
    # Up Block 6
    attn4 = attention_gate(conv4, conv5, inter_channels=256, name_prefix='attn4')
    up6 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same', name='block6_dconv')(conv5)
    up6 = concatenate([up6, attn4], axis=3, name='block6_concat')
    conv6 = Conv2D(256, (3, 3), padding='same', name='block6_conv')(up6)
    conv6 = BatchNormalization(name='block6_bn')(conv6)
    conv6 = Activation('relu', name='block6_relu')(conv6)
    # SE
    conv6 = se_block(conv6, 256, 'block6_se')

    # Up Block 7
    attn3 = attention_gate(conv3, conv6, inter_channels=128, name_prefix='attn3')
    up7 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same', name='block7_dconv')(conv6)
    up7 = concatenate([up7, attn3], axis=3, name='block7_concat')
    conv7 = Conv2D(128, (3, 3), padding='same', name='block7_conv')(up7)
    conv7 = BatchNormalization(name='block7_bn')(conv7)
    conv7 = Activation('relu', name='block7_relu')(conv7)
    # SE
    conv7 = se_block(conv7, 128, 'block7_se')

    # Up Block 8
    attn2 = attention_gate(conv2, conv7, inter_channels=64, name_prefix='attn2')
    up8 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same', name='block8_dconv')(conv7)
    up8 = concatenate([up8, attn2], axis=3, name='block8_concat')
    conv8 = Conv2D(64, (3, 3), padding='same', name='block8_conv')(up8)
    conv8 = BatchNormalization(name='block8_bn')(conv8)
    conv8 = Activation('relu', name='block8_relu')(conv8)
    # SE
    conv8 = se_block(conv8, 64, 'block8_se')

    # Up Block 9
    attn1 = attention_gate(conv1, conv8, inter_channels=32, name_prefix='attn1')
    up9 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same', name='block9_dconv')(conv8)
    up9 = concatenate([up9, attn1], axis=3, name='block9_concat')
    conv9 = Conv2D(32, (3, 3), padding='same', name='block9_conv')(up9)
    conv9 = BatchNormalization(name='block9_bn')(conv9)
    conv9 = Activation('relu', name='block9_relu')(conv9)
    # SE
    conv9 = se_block(conv9, 32, 'block9_se')

    # ----- Side Outputs (for deep supervision) -----
    side6 = UpSampling2D(size=(8, 8), name='side6_upsample')(conv6)
    side7 = UpSampling2D(size=(4, 4), name='side7_upsample')(conv7)
    side8 = UpSampling2D(size=(2, 2), name='side8_upsample')(conv8)

    out6 = Conv2D(3, (1, 1), activation='softmax', name='side_63')(side6)
    out7 = Conv2D(3, (1, 1), activation='softmax', name='side_73')(side7)
    out8 = Conv2D(3, (1, 1), activation='softmax', name='side_83')(side8)
    out9 = Conv2D(3, (1, 1), activation='softmax', name='side_93')(conv9)

    # ----- Final Output: Average of side outputs -----
    out10 = Average(name='final_output')([out6, out7, out8, out9])

    # ----- Define the model -----
    model = Model(inputs=[img_input], outputs=[out6, out7, out8, out9, out10],
                  name='DeepModel_with_SE_in_Decoder')

    return model

# %% [markdown]
# # Training

# %%
# # Set the root and data paths
# root_path = '/kaggle/input/training-data-polar/training_crop/'
# train_data_path = os.path.join(root_path, 'data/')
# train_mask_path = os.path.join(root_path, 'label/')

# val_data_path = os.path.join(root_path, 'val_data/data/')
# val_mask_path = os.path.join(root_path, 'val_data/label/')

# # Define image dimensions
# IMAGE_SIZE = 800  # As per your model's input size

# # Function to load and preprocess images
# def load_image(path, target_size):
#     img = load_img(path, target_size=(target_size, target_size))
#     img = img_to_array(img)
#     img = img / 255.0  # Normalize to [0, 1]
#     return img

# # Function to load and preprocess masks
# def load_mask(path, target_size):
#     mask = load_img(path, target_size=(target_size, target_size), color_mode='grayscale')
#     mask = img_to_array(mask)
#     mask = mask / 255.0  # Normalize to [0, 1]
#     mask = np.round(mask)  # Ensure binary masks
#     return mask

# # Custom data generator
# class DataGenerator(Sequence):
#     def __init__(self, image_filenames, mask_filenames, image_dir, mask_dir, batch_size, target_size, shuffle=True):
#         self.image_filenames = image_filenames
#         self.mask_filenames = mask_filenames
#         self.image_dir = image_dir
#         self.mask_dir = mask_dir
#         self.batch_size = batch_size
#         self.target_size = target_size
#         self.shuffle = shuffle
#         self.on_epoch_end()
    
#     def __len__(self):
#         return int(np.ceil(len(self.image_filenames) / self.batch_size))
    
#     def __getitem__(self, index):
#         # Generate indexes of the batch
#         batch_indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        
#         # Find list of IDs
#         batch_image_filenames = [self.image_filenames[k] for k in batch_indexes]
#         batch_mask_filenames = [self.mask_filenames[k] for k in batch_indexes]
        
#         # Generate data
#         X, Y = self.__data_generation(batch_image_filenames, batch_mask_filenames)
        
#         return X, Y
    
#     def on_epoch_end(self):
#         self.indexes = np.arange(len(self.image_filenames))
#         if self.shuffle:
#             np.random.shuffle(self.indexes)
    
#     def __data_generation(self, batch_image_filenames, batch_mask_filenames):
#         X = np.empty((len(batch_image_filenames), self.target_size, self.target_size, 3), dtype=np.float32)
#         Y = np.empty((len(batch_mask_filenames), self.target_size, self.target_size, 1), dtype=np.float32)
        
#         for i, (img_name, mask_name) in enumerate(zip(batch_image_filenames, batch_mask_filenames)):
#             img_path = os.path.join(self.image_dir, img_name)
#             mask_path = os.path.join(self.mask_dir, mask_name)
            
#             # Load and preprocess images and masks
#             img = load_image(img_path, self.target_size)
#             mask = load_mask(mask_path, self.target_size)
            
#             X[i] = img
#             Y[i] = mask
        
#         # Prepare outputs as a dictionary mapping output names to targets
#         Y_multi = {
#             'side_63': Y,
#             'side_73': Y,
#             'side_83': Y,
#             'side_93': Y,
#             'final_output': Y
#         }
#         return X, Y_multi


# # Get the list of image and mask filenames for training
# train_image_files = sorted(os.listdir(train_data_path))
# train_mask_files = sorted(os.listdir(train_mask_path))

# # Get the list of image and mask filenames for validation
# val_image_files = sorted(os.listdir(val_data_path))
# val_mask_files = sorted(os.listdir(val_mask_path))

# # Create data generators
# batch_size = 4  # Adjust based on your GPU memory

# train_generator = DataGenerator(
#     train_image_files, train_mask_files,
#     train_data_path, train_mask_path,
#     batch_size=batch_size, target_size=IMAGE_SIZE, shuffle=True
# )

# val_generator = DataGenerator(
#     val_image_files, val_mask_files,
#     val_data_path, val_mask_path,
#     batch_size=batch_size, target_size=IMAGE_SIZE, shuffle=False
# )

# # Define the model
# model = DeepModel(size_set=IMAGE_SIZE)

# # Compile the model with dictionaries for losses and loss_weights
# losses = {
#     'side_63': 'binary_crossentropy',
#     'side_73': 'binary_crossentropy',
#     'side_83': 'binary_crossentropy',
#     'side_93': 'binary_crossentropy',
#     'final_output': 'binary_crossentropy'
# }

# loss_weights = {
#     'side_63': 0.1,
#     'side_73': 0.1,
#     'side_83': 0.1,
#     'side_93': 0.1,
#     'final_output': 0.6
# }

# def dice_coefficient(y_true, y_pred):
#     smooth = 1.  # Avoid division by zero
#     y_true_f = K.flatten(y_true)
#     y_pred_f = K.flatten(y_pred)
#     intersection = K.sum(y_true_f * y_pred_f)
#     return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# metrics = {
#     'side_63': ['accuracy'],
#     'side_73': ['accuracy'],
#     'side_83': ['accuracy'],
#     'side_93': ['accuracy'],
#     'final_output': ['accuracy']#, dice_coefficie
# }

# model.compile(
#     optimizer=Adam(learning_rate=1e-4),
#     loss=losses,
#     loss_weights=loss_weights,
#     metrics= metrics,
# )

# # Callbacks
# checkpoint = ModelCheckpoint(
#     '/kaggle/working/best_model.weights.h5',
#     monitor='val_loss',
#     verbose=1,
#     save_best_only=True,
#     mode='min',
#     save_weights_only=True
# )

# reduce_lr = ReduceLROnPlateau(
#     monitor='val_loss',
#     factor=0.5,
#     patience=5,
#     min_lr=1e-7,
#     verbose=1
# )

# early_stopping = EarlyStopping(
#     monitor='val_loss',
#     patience=10,
#     restore_best_weights=True
# )

# callbacks_list = [checkpoint, reduce_lr, early_stopping]

# # Train the model
# epochs = 50  # Adjust as needed
# print("Start training")
# model.fit(
#     train_generator,
#     validation_data=val_generator,
#     epochs=epochs,
#     callbacks=callbacks_list
# )

# %%
# Define the Dice Loss function
def dice_loss(y_true, y_pred, smooth=1e-6):
    """
    Dice Loss for multiclass segmentation.
    """
    y_true_f = tf.reshape(y_true, [-1, tf.shape(y_true)[-1]])
    y_pred_f = tf.reshape(y_pred, [-1, tf.shape(y_pred)[-1]])
    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
    denominator = tf.reduce_sum(y_true_f + y_pred_f, axis=0)
    dice_score = (2. * intersection + smooth) / (denominator + smooth)
    return 1 - tf.reduce_mean(dice_score)

# %%
# Total_iter = 50
# nb_epoch_setting = 10
# input_size = 224
# #optimizer_setting = SGD(learning_rate=0.0001, momentum=0.9)
# optimizer_setting = Adam(learning_rate=0.0001, use_ema = True)

# # Build and compile the model
# my_model = DeepModel(size_set=input_size)
# # my_model.load_weights(pre_model_file, by_name=True)

# my_model.compile(optimizer=optimizer_setting, loss='categorical_crossentropy',
#                  loss_weights=[0.1, 0.1, 0.1, 0.1, 0.6])

# print(my_model.input_shape)  # Should output (None, 400, 400, 3)

# # Data Preparation
# train_dataset = tf_data_loader(train_list, train_data_path, train_mask_path, input_size)
# val_dataset = tf_data_loader(val_list, val_data_path, val_mask_path, input_size)

# train_dataset = train_dataset.shuffle(buffer_size=len(train_list)).batch(4).repeat().prefetch(tf.data.AUTOTUNE)
# val_dataset = val_dataset.batch(4).repeat().prefetch(tf.data.AUTOTUNE)

# batch_size = 4
# steps_per_epoch = len(train_list) // batch_size
# validation_steps = len(val_list) // batch_size

# # Verify data shapes
# for images, labels in train_dataset.take(1):
#     print("Image shape:", images.shape)  # Expected: (batch_size, input_size, input_size, 3)
#     for idx, label in enumerate(labels):
#         print(f"Label {idx+1} shape:", label.shape)  # Expected: (batch_size, input_size, input_size, 3)

# # Training Loop
# loss_max = 10000
# for idx_iter in range(Total_iter):
#     print("Training started")
#     model_return = my_model.fit(
#         x=train_dataset,
#         validation_data=val_dataset,
#         epochs=nb_epoch_setting,
#         steps_per_epoch=steps_per_epoch,
#         validation_steps=validation_steps,
#         verbose=1
#     )
#     val_loss = model_return.history['val_loss'][0]
#     train_loss = model_return.history['loss'][0]
#     if val_loss < loss_max:
#         my_model.save(save_model_file)
#         loss_max = val_loss
#         print('[Save] training iter: ' + str(idx_iter+1) +
#               ', train_loss: ' + str(train_loss) +
#               ', val_loss: ' + str(val_loss))
#     else:
#         print('[None] training iter: ' + str(idx_iter+1) +
#               ', train_loss: ' + str(train_loss) +
#               ', val_loss: ' + str(val_loss))

# %%
input_size = 224
batch_size = 8
epochs = 200  # Total number of epochs to train

train_list = return_list(train_data_path, '.png')
val_list = return_list(val_data_path, '.png')

# Create TensorFlow datasets
train_dataset = tf_data_loader(train_list, train_data_path, train_mask_path, input_size)
val_dataset = tf_data_loader(val_list, val_data_path, val_mask_path, input_size)

# Calculate steps per epoch
steps_per_epoch = len(train_list) // batch_size
validation_steps = len(val_list) // batch_size

# Prepare the datasets
train_dataset = (
    train_dataset
    .shuffle(buffer_size=len(train_list), reshuffle_each_iteration=True)
    .batch(batch_size)
    .repeat()  # Repeat indefinitely
    .prefetch(tf.data.AUTOTUNE)
)
val_dataset = (
    val_dataset
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)


# Initialize the model
my_model = DeepModel(size_set=input_size)

# Define the optimizer
optimizer_setting = SGD(learning_rate=0.0001, momentum=0.9)

# Compile the model
my_model.compile(
    optimizer=optimizer_setting,
    loss=dice_loss,
    loss_weights=[0.1, 0.1, 0.1, 0.1, 0.6]
)

my_model.load_weights('/kaggle/input/model-se/Model_MNet_SE.keras')

# Define callbacks for saving the best model and early stopping
checkpoint = ModelCheckpoint(
    filepath=save_model_file,
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1
)

# # Train the model
history = my_model.fit(
    train_dataset,
    epochs=epochs,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_dataset,
    validation_steps=validation_steps,
    callbacks=[checkpoint, early_stopping],
    verbose=1
)

#my_model.load_weights('/kaggle/input/weights/Model_MNet_ATT_Res.keras')
# Out:
# 1400
# 300
# Epoch 1/200
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:576: UserWarning: Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 146 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.5552
# Epoch 1: val_loss improved from inf to 0.55006, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 102s 183ms/step - loss: 0.5552 - val_loss: 0.5501
# Epoch 2/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.5542
# Epoch 2: val_loss did not improve from 0.55006
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 34s 132ms/step - loss: 0.5542 - val_loss: 0.5600
# Epoch 3/200
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.5542
# Epoch 3: val_loss improved from 0.55006 to 0.54924, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 40s 139ms/step - loss: 0.5542 - val_loss: 0.5492
# Epoch 4/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.5532
# Epoch 4: val_loss did not improve from 0.54924
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 34s 106ms/step - loss: 0.5532 - val_loss: 0.5592
# Epoch 5/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.5543
# Epoch 5: val_loss improved from 0.54924 to 0.54833, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 45s 141ms/step - loss: 0.5543 - val_loss: 0.5483
# Epoch 6/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.5530
# Epoch 6: val_loss did not improve from 0.54833
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 106ms/step - loss: 0.5530 - val_loss: 0.5584
# Epoch 7/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.5523
# Epoch 7: val_loss improved from 0.54833 to 0.54773, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 42s 140ms/step - loss: 0.5523 - val_loss: 0.5477
# Epoch 8/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.5503
# Epoch 8: val_loss did not improve from 0.54773
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 106ms/step - loss: 0.5503 - val_loss: 0.5576
# Epoch 9/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5532
# Epoch 9: val_loss improved from 0.54773 to 0.54689, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 142ms/step - loss: 0.5532 - val_loss: 0.5469
# Epoch 10/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5507
# Epoch 10: val_loss did not improve from 0.54689
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5507 - val_loss: 0.5567
# Epoch 11/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5508
# Epoch 11: val_loss improved from 0.54689 to 0.54616, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 29s 142ms/step - loss: 0.5508 - val_loss: 0.5462
# Epoch 12/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5510
# Epoch 12: val_loss did not improve from 0.54616
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5510 - val_loss: 0.5556
# Epoch 13/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5501
# Epoch 13: val_loss improved from 0.54616 to 0.54527, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - loss: 0.5501 - val_loss: 0.5453
# Epoch 14/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5490
# Epoch 14: val_loss did not improve from 0.54527
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5490 - val_loss: 0.5550
# Epoch 15/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5492
# Epoch 15: val_loss improved from 0.54527 to 0.54459, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 142ms/step - loss: 0.5492 - val_loss: 0.5446
# Epoch 16/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5479
# Epoch 16: val_loss did not improve from 0.54459
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5479 - val_loss: 0.5540
# Epoch 17/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5484
# Epoch 17: val_loss improved from 0.54459 to 0.54367, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 141ms/step - loss: 0.5484 - val_loss: 0.5437
# Epoch 18/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5467
# Epoch 18: val_loss did not improve from 0.54367
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5467 - val_loss: 0.5532
# Epoch 19/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.5470
# Epoch 19: val_loss improved from 0.54367 to 0.54295, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - loss: 0.5470 - val_loss: 0.5430
# Epoch 20/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5486
# Epoch 20: val_loss did not improve from 0.54295
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5486 - val_loss: 0.5525
# Epoch 21/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5468
# Epoch 21: val_loss improved from 0.54295 to 0.54223, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - loss: 0.5468 - val_loss: 0.5422
# Epoch 22/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5460
# Epoch 22: val_loss did not improve from 0.54223
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5460 - val_loss: 0.5516
# Epoch 23/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5448
# Epoch 23: val_loss improved from 0.54223 to 0.54137, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - loss: 0.5448 - val_loss: 0.5414
# Epoch 24/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5448
# Epoch 24: val_loss did not improve from 0.54137
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5448 - val_loss: 0.5507
# Epoch 25/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5463
# Epoch 25: val_loss improved from 0.54137 to 0.54061, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 142ms/step - loss: 0.5463 - val_loss: 0.5406
# Epoch 26/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5443
# Epoch 26: val_loss did not improve from 0.54061
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5443 - val_loss: 0.5498
# Epoch 27/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5453
# Epoch 27: val_loss improved from 0.54061 to 0.53975, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 142ms/step - loss: 0.5453 - val_loss: 0.5398
# Epoch 28/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5429
# Epoch 28: val_loss did not improve from 0.53975
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5429 - val_loss: 0.5490
# Epoch 29/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5426
# Epoch 29: val_loss improved from 0.53975 to 0.53909, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 142ms/step - loss: 0.5426 - val_loss: 0.5391
# Epoch 30/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5429
# Epoch 30: val_loss did not improve from 0.53909
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5429 - val_loss: 0.5479
# Epoch 31/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5423
# Epoch 31: val_loss improved from 0.53909 to 0.53836, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - loss: 0.5423 - val_loss: 0.5384
# Epoch 32/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5402
# Epoch 32: val_loss did not improve from 0.53836
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5402 - val_loss: 0.5470
# Epoch 33/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5421
# Epoch 33: val_loss improved from 0.53836 to 0.53745, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - loss: 0.5421 - val_loss: 0.5374
# Epoch 34/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5423
# Epoch 34: val_loss did not improve from 0.53745
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5423 - val_loss: 0.5462
# Epoch 35/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5414
# Epoch 35: val_loss improved from 0.53745 to 0.53669, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - loss: 0.5414 - val_loss: 0.5367
# Epoch 36/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5418
# Epoch 36: val_loss did not improve from 0.53669
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5417 - val_loss: 0.5452
# Epoch 37/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5398
# Epoch 37: val_loss improved from 0.53669 to 0.53586, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 143ms/step - loss: 0.5398 - val_loss: 0.5359
# Epoch 38/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5385
# Epoch 38: val_loss did not improve from 0.53586
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5385 - val_loss: 0.5441
# Epoch 39/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5398
# Epoch 39: val_loss improved from 0.53586 to 0.53506, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 29s 141ms/step - loss: 0.5398 - val_loss: 0.5351
# Epoch 40/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5389
# Epoch 40: val_loss did not improve from 0.53506
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5389 - val_loss: 0.5437
# Epoch 41/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5390
# Epoch 41: val_loss improved from 0.53506 to 0.53443, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5390 - val_loss: 0.5344
# Epoch 42/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5379
# Epoch 42: val_loss did not improve from 0.53443
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5379 - val_loss: 0.5428
# Epoch 43/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5384
# Epoch 43: val_loss improved from 0.53443 to 0.53350, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - loss: 0.5384 - val_loss: 0.5335
# Epoch 44/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5360
# Epoch 44: val_loss did not improve from 0.53350
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5360 - val_loss: 0.5415
# Epoch 45/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5366
# Epoch 45: val_loss improved from 0.53350 to 0.53274, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5366 - val_loss: 0.5327
# Epoch 46/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5354
# Epoch 46: val_loss did not improve from 0.53274
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5354 - val_loss: 0.5412
# Epoch 47/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5361
# Epoch 47: val_loss improved from 0.53274 to 0.53208, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 141ms/step - loss: 0.5361 - val_loss: 0.5321
# Epoch 48/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5339
# Epoch 48: val_loss did not improve from 0.53208
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5340 - val_loss: 0.5402
# Epoch 49/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5351
# Epoch 49: val_loss improved from 0.53208 to 0.53150, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 141ms/step - loss: 0.5351 - val_loss: 0.5315
# Epoch 50/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5347
# Epoch 50: val_loss did not improve from 0.53150
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5347 - val_loss: 0.5388
# Epoch 51/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5336
# Epoch 51: val_loss improved from 0.53150 to 0.53057, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 142ms/step - loss: 0.5336 - val_loss: 0.5306
# Epoch 52/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5336
# Epoch 52: val_loss did not improve from 0.53057
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5336 - val_loss: 0.5386
# Epoch 53/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5340
# Epoch 53: val_loss improved from 0.53057 to 0.52996, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - loss: 0.5340 - val_loss: 0.5300
# Epoch 54/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5335
# Epoch 54: val_loss did not improve from 0.52996
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5335 - val_loss: 0.5380
# Epoch 55/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5328
# Epoch 55: val_loss improved from 0.52996 to 0.52926, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5328 - val_loss: 0.5293
# Epoch 56/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5322
# Epoch 56: val_loss did not improve from 0.52926
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5322 - val_loss: 0.5367
# Epoch 57/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5315
# Epoch 57: val_loss improved from 0.52926 to 0.52860, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - loss: 0.5315 - val_loss: 0.5286
# Epoch 58/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5318
# Epoch 58: val_loss did not improve from 0.52860
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5318 - val_loss: 0.5357
# Epoch 59/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5320
# Epoch 59: val_loss improved from 0.52860 to 0.52798, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5320 - val_loss: 0.5280
# Epoch 60/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.5314
# Epoch 60: val_loss did not improve from 0.52798
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5314 - val_loss: 0.5352
# Epoch 61/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5303
# Epoch 61: val_loss improved from 0.52798 to 0.52727, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - loss: 0.5303 - val_loss: 0.5273
# Epoch 62/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5298
# Epoch 62: val_loss did not improve from 0.52727
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5298 - val_loss: 0.5346
# Epoch 63/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5282
# Epoch 63: val_loss improved from 0.52727 to 0.52679, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - loss: 0.5282 - val_loss: 0.5268
# Epoch 64/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5288
# Epoch 64: val_loss did not improve from 0.52679
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5288 - val_loss: 0.5341
# Epoch 65/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5283
# Epoch 65: val_loss improved from 0.52679 to 0.52620, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 139ms/step - loss: 0.5283 - val_loss: 0.5262
# Epoch 66/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5288
# Epoch 66: val_loss did not improve from 0.52620
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5288 - val_loss: 0.5331
# Epoch 67/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5287
# Epoch 67: val_loss improved from 0.52620 to 0.52558, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - loss: 0.5287 - val_loss: 0.5256
# Epoch 68/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5283
# Epoch 68: val_loss did not improve from 0.52558
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5283 - val_loss: 0.5319
# Epoch 69/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5288
# Epoch 69: val_loss improved from 0.52558 to 0.52497, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5287 - val_loss: 0.5250
# Epoch 70/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5292
# Epoch 70: val_loss did not improve from 0.52497
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5292 - val_loss: 0.5320
# Epoch 71/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5283
# Epoch 71: val_loss improved from 0.52497 to 0.52411, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - loss: 0.5283 - val_loss: 0.5241
# Epoch 72/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5285
# Epoch 72: val_loss did not improve from 0.52411
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5285 - val_loss: 0.5313
# Epoch 73/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5283
# Epoch 73: val_loss improved from 0.52411 to 0.52343, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - loss: 0.5283 - val_loss: 0.5234
# Epoch 74/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5254
# Epoch 74: val_loss did not improve from 0.52343
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5254 - val_loss: 0.5303
# Epoch 75/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5264
# Epoch 75: val_loss improved from 0.52343 to 0.52310, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5264 - val_loss: 0.5231
# Epoch 76/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5258
# Epoch 76: val_loss did not improve from 0.52310
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5258 - val_loss: 0.5304
# Epoch 77/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5241
# Epoch 77: val_loss improved from 0.52310 to 0.52264, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - loss: 0.5241 - val_loss: 0.5226
# Epoch 78/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5242
# Epoch 78: val_loss did not improve from 0.52264
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5242 - val_loss: 0.5292
# Epoch 79/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5242
# Epoch 79: val_loss improved from 0.52264 to 0.52211, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5242 - val_loss: 0.5221
# Epoch 80/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5247
# Epoch 80: val_loss did not improve from 0.52211
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5247 - val_loss: 0.5282
# Epoch 81/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5234
# Epoch 81: val_loss improved from 0.52211 to 0.52141, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5234 - val_loss: 0.5214
# Epoch 82/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.5225
# Epoch 82: val_loss did not improve from 0.52141
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5225 - val_loss: 0.5282
# Epoch 83/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5216
# Epoch 83: val_loss improved from 0.52141 to 0.52090, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - loss: 0.5216 - val_loss: 0.5209
# Epoch 84/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.5226
# Epoch 84: val_loss did not improve from 0.52090
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5226 - val_loss: 0.5273
# Epoch 85/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5230
# Epoch 85: val_loss improved from 0.52090 to 0.52046, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - loss: 0.5230 - val_loss: 0.5205
# Epoch 86/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5230
# Epoch 86: val_loss did not improve from 0.52046
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5230 - val_loss: 0.5262
# Epoch 87/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5220
# Epoch 87: val_loss improved from 0.52046 to 0.51986, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5220 - val_loss: 0.5199
# Epoch 88/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5226
# Epoch 88: val_loss did not improve from 0.51986
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5226 - val_loss: 0.5262
# Epoch 89/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5207
# Epoch 89: val_loss improved from 0.51986 to 0.51914, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5207 - val_loss: 0.5191
# Epoch 90/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5201
# Epoch 90: val_loss did not improve from 0.51914
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5201 - val_loss: 0.5257
# Epoch 91/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5218
# Epoch 91: val_loss improved from 0.51914 to 0.51855, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5218 - val_loss: 0.5186
# Epoch 92/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.5221
# Epoch 92: val_loss did not improve from 0.51855
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5221 - val_loss: 0.5243
# Epoch 93/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5213
# Epoch 93: val_loss did not improve from 0.51855
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 135ms/step - loss: 0.5213 - val_loss: 0.5186
# Epoch 94/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5198
# Epoch 94: val_loss did not improve from 0.51855
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5198 - val_loss: 0.5242
# Epoch 95/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5196
# Epoch 95: val_loss improved from 0.51855 to 0.51772, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5196 - val_loss: 0.5177
# Epoch 96/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.5212
# Epoch 96: val_loss did not improve from 0.51772
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5212 - val_loss: 0.5231
# Epoch 97/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5210
# Epoch 97: val_loss improved from 0.51772 to 0.51718, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5210 - val_loss: 0.5172
# Epoch 98/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5186
# Epoch 98: val_loss did not improve from 0.51718
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5186 - val_loss: 0.5223
# Epoch 99/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5187
# Epoch 99: val_loss improved from 0.51718 to 0.51659, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - loss: 0.5187 - val_loss: 0.5166
# Epoch 100/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5191
# Epoch 100: val_loss did not improve from 0.51659
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5191 - val_loss: 0.5221
# Epoch 101/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5179
# Epoch 101: val_loss improved from 0.51659 to 0.51600, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5179 - val_loss: 0.5160
# Epoch 102/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5191
# Epoch 102: val_loss did not improve from 0.51600
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5191 - val_loss: 0.5214
# Epoch 103/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5196
# Epoch 103: val_loss improved from 0.51600 to 0.51559, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 139ms/step - loss: 0.5196 - val_loss: 0.5156
# Epoch 104/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5167
# Epoch 104: val_loss did not improve from 0.51559
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5167 - val_loss: 0.5211
# Epoch 105/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5180
# Epoch 105: val_loss improved from 0.51559 to 0.51486, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5180 - val_loss: 0.5149
# Epoch 106/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.5166
# Epoch 106: val_loss did not improve from 0.51486
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5166 - val_loss: 0.5202
# Epoch 107/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5163
# Epoch 107: val_loss improved from 0.51486 to 0.51443, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5163 - val_loss: 0.5144
# Epoch 108/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5177
# Epoch 108: val_loss did not improve from 0.51443
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5177 - val_loss: 0.5194
# Epoch 109/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5170
# Epoch 109: val_loss improved from 0.51443 to 0.51383, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 142ms/step - loss: 0.5170 - val_loss: 0.5138
# Epoch 110/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5169
# Epoch 110: val_loss did not improve from 0.51383
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5169 - val_loss: 0.5189
# Epoch 111/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5140
# Epoch 111: val_loss did not improve from 0.51383
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 26s 135ms/step - loss: 0.5140 - val_loss: 0.5139
# Epoch 112/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5152
# Epoch 112: val_loss did not improve from 0.51383
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5152 - val_loss: 0.5188
# Epoch 113/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5156
# Epoch 113: val_loss improved from 0.51383 to 0.51313, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - loss: 0.5156 - val_loss: 0.5131
# Epoch 114/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5162
# Epoch 114: val_loss did not improve from 0.51313
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5162 - val_loss: 0.5183
# Epoch 115/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5151
# Epoch 115: val_loss improved from 0.51313 to 0.51276, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 139ms/step - loss: 0.5151 - val_loss: 0.5128
# Epoch 116/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.5143
# Epoch 116: val_loss did not improve from 0.51276
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5143 - val_loss: 0.5182
# Epoch 117/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5138
# Epoch 117: val_loss improved from 0.51276 to 0.51215, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 139ms/step - loss: 0.5138 - val_loss: 0.5122
# Epoch 118/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5160
# Epoch 118: val_loss did not improve from 0.51215
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5160 - val_loss: 0.5162
# Epoch 119/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5142
# Epoch 119: val_loss improved from 0.51215 to 0.51172, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 141ms/step - loss: 0.5142 - val_loss: 0.5117
# Epoch 120/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5118
# Epoch 120: val_loss did not improve from 0.51172
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5118 - val_loss: 0.5174
# Epoch 121/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5138
# Epoch 121: val_loss improved from 0.51172 to 0.51145, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - loss: 0.5138 - val_loss: 0.5115
# Epoch 122/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5128
# Epoch 122: val_loss did not improve from 0.51145
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5128 - val_loss: 0.5165
# Epoch 123/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5114
# Epoch 123: val_loss improved from 0.51145 to 0.51122, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - loss: 0.5114 - val_loss: 0.5112
# Epoch 124/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5123
# Epoch 124: val_loss did not improve from 0.51122
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5123 - val_loss: 0.5169
# Epoch 125/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5113
# Epoch 125: val_loss improved from 0.51122 to 0.51104, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5113 - val_loss: 0.5110
# Epoch 126/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5115
# Epoch 126: val_loss did not improve from 0.51104
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5115 - val_loss: 0.5162
# Epoch 127/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5112
# Epoch 127: val_loss improved from 0.51104 to 0.51020, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 141ms/step - loss: 0.5112 - val_loss: 0.5102
# Epoch 128/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5117
# Epoch 128: val_loss did not improve from 0.51020
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5117 - val_loss: 0.5146
# Epoch 129/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5099
# Epoch 129: val_loss improved from 0.51020 to 0.51009, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5099 - val_loss: 0.5101
# Epoch 130/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5106
# Epoch 130: val_loss did not improve from 0.51009
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5106 - val_loss: 0.5145
# Epoch 131/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5099
# Epoch 131: val_loss improved from 0.51009 to 0.50941, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 141ms/step - loss: 0.5099 - val_loss: 0.5094
# Epoch 132/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5113
# Epoch 132: val_loss did not improve from 0.50941
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5113 - val_loss: 0.5151
# Epoch 133/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5107
# Epoch 133: val_loss improved from 0.50941 to 0.50921, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - loss: 0.5107 - val_loss: 0.5092
# Epoch 134/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5104
# Epoch 134: val_loss did not improve from 0.50921
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5104 - val_loss: 0.5143
# Epoch 135/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5092
# Epoch 135: val_loss improved from 0.50921 to 0.50898, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5092 - val_loss: 0.5090
# Epoch 136/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5100
# Epoch 136: val_loss did not improve from 0.50898
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5100 - val_loss: 0.5147
# Epoch 137/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5090
# Epoch 137: val_loss improved from 0.50898 to 0.50842, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - loss: 0.5090 - val_loss: 0.5084
# Epoch 138/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5101
# Epoch 138: val_loss did not improve from 0.50842
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5101 - val_loss: 0.5124
# Epoch 139/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5080
# Epoch 139: val_loss did not improve from 0.50842
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 26s 137ms/step - loss: 0.5080 - val_loss: 0.5085
# Epoch 140/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5094
# Epoch 140: val_loss did not improve from 0.50842
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5094 - val_loss: 0.5117
# Epoch 141/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5091
# Epoch 141: val_loss improved from 0.50842 to 0.50761, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - loss: 0.5091 - val_loss: 0.5076
# Epoch 142/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5078
# Epoch 142: val_loss did not improve from 0.50761
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5078 - val_loss: 0.5131
# Epoch 143/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5091
# Epoch 143: val_loss improved from 0.50761 to 0.50733, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5091 - val_loss: 0.5073
# Epoch 144/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.5083
# Epoch 144: val_loss did not improve from 0.50733
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5083 - val_loss: 0.5125
# Epoch 145/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5064
# Epoch 145: val_loss improved from 0.50733 to 0.50669, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 140ms/step - loss: 0.5064 - val_loss: 0.5067
# Epoch 146/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5092
# Epoch 146: val_loss did not improve from 0.50669
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5092 - val_loss: 0.5118
# Epoch 147/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5076
# Epoch 147: val_loss improved from 0.50669 to 0.50662, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 141ms/step - loss: 0.5076 - val_loss: 0.5066
# Epoch 148/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5082
# Epoch 148: val_loss did not improve from 0.50662
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5082 - val_loss: 0.5112
# Epoch 149/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5061
# Epoch 149: val_loss did not improve from 0.50662
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 135ms/step - loss: 0.5062 - val_loss: 0.5071
# Epoch 150/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5072
# Epoch 150: val_loss did not improve from 0.50662
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5072 - val_loss: 0.5105
# Epoch 151/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5078
# Epoch 151: val_loss did not improve from 0.50662
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 136ms/step - loss: 0.5078 - val_loss: 0.5071
# Epoch 152/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5061
# Epoch 152: val_loss did not improve from 0.50662
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 19s 105ms/step - loss: 0.5061 - val_loss: 0.5114
# Epoch 153/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5058
# Epoch 153: val_loss improved from 0.50662 to 0.50643, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 30s 139ms/step - loss: 0.5058 - val_loss: 0.5064
# Epoch 154/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5064
# Epoch 154: val_loss did not improve from 0.50643
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 19s 105ms/step - loss: 0.5064 - val_loss: 0.5105
# Epoch 155/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5058
# Epoch 155: val_loss improved from 0.50643 to 0.50592, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 30s 141ms/step - loss: 0.5058 - val_loss: 0.5059
# Epoch 156/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5032
# Epoch 156: val_loss did not improve from 0.50592
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 19s 105ms/step - loss: 0.5032 - val_loss: 0.5115
# Epoch 157/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5063
# Epoch 157: val_loss improved from 0.50592 to 0.50507, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 30s 140ms/step - loss: 0.5063 - val_loss: 0.5051
# Epoch 158/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5041
# Epoch 158: val_loss did not improve from 0.50507
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 19s 105ms/step - loss: 0.5041 - val_loss: 0.5089
# Epoch 159/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5054
# Epoch 159: val_loss improved from 0.50507 to 0.50462, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 30s 143ms/step - loss: 0.5054 - val_loss: 0.5046
# Epoch 160/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.5075
# Epoch 160: val_loss did not improve from 0.50462
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5075 - val_loss: 0.5108
# Epoch 161/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5026
# Epoch 161: val_loss did not improve from 0.50462
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 135ms/step - loss: 0.5026 - val_loss: 0.5050
# Epoch 162/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5050
# Epoch 162: val_loss did not improve from 0.50462
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5050 - val_loss: 0.5087
# Epoch 163/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5052
# Epoch 163: val_loss did not improve from 0.50462
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 134ms/step - loss: 0.5052 - val_loss: 0.5048
# Epoch 164/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5044
# Epoch 164: val_loss did not improve from 0.50462
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5044 - val_loss: 0.5093
# Epoch 165/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5056
# Epoch 165: val_loss improved from 0.50462 to 0.50441, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 30s 141ms/step - loss: 0.5056 - val_loss: 0.5044
# Epoch 166/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5044
# Epoch 166: val_loss did not improve from 0.50441
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5044 - val_loss: 0.5090
# Epoch 167/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5032
# Epoch 167: val_loss did not improve from 0.50441
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 136ms/step - loss: 0.5032 - val_loss: 0.5047
# Epoch 168/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5037
# Epoch 168: val_loss did not improve from 0.50441
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5037 - val_loss: 0.5077
# Epoch 169/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5023
# Epoch 169: val_loss improved from 0.50441 to 0.50401, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - loss: 0.5023 - val_loss: 0.5040
# Epoch 170/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.5039
# Epoch 170: val_loss did not improve from 0.50401
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5039 - val_loss: 0.5069
# Epoch 171/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5026
# Epoch 171: val_loss improved from 0.50401 to 0.50326, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 142ms/step - loss: 0.5026 - val_loss: 0.5033
# Epoch 172/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5035
# Epoch 172: val_loss did not improve from 0.50326
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5035 - val_loss: 0.5079
# Epoch 173/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5031
# Epoch 173: val_loss did not improve from 0.50326
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 136ms/step - loss: 0.5031 - val_loss: 0.5034
# Epoch 174/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5045
# Epoch 174: val_loss did not improve from 0.50326
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5045 - val_loss: 0.5076
# Epoch 175/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5020
# Epoch 175: val_loss improved from 0.50326 to 0.50257, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - loss: 0.5020 - val_loss: 0.5026
# Epoch 176/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5034
# Epoch 176: val_loss did not improve from 0.50257
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5034 - val_loss: 0.5044
# Epoch 177/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5034
# Epoch 177: val_loss improved from 0.50257 to 0.50246, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - loss: 0.5034 - val_loss: 0.5025
# Epoch 178/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5015
# Epoch 178: val_loss did not improve from 0.50246
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5015 - val_loss: 0.5061
# Epoch 179/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5027
# Epoch 179: val_loss did not improve from 0.50246
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 135ms/step - loss: 0.5027 - val_loss: 0.5029
# Epoch 180/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5000
# Epoch 180: val_loss did not improve from 0.50246
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 19s 105ms/step - loss: 0.5000 - val_loss: 0.5089
# Epoch 181/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5018
# Epoch 181: val_loss improved from 0.50246 to 0.50197, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 30s 142ms/step - loss: 0.5018 - val_loss: 0.5020
# Epoch 182/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5018
# Epoch 182: val_loss did not improve from 0.50197
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5018 - val_loss: 0.5067
# Epoch 183/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5010
# Epoch 183: val_loss did not improve from 0.50197
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 29s 136ms/step - loss: 0.5010 - val_loss: 0.5022
# Epoch 184/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.4990
# Epoch 184: val_loss did not improve from 0.50197
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 19s 105ms/step - loss: 0.4991 - val_loss: 0.5071
# Epoch 185/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5018
# Epoch 185: val_loss did not improve from 0.50197
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 135ms/step - loss: 0.5018 - val_loss: 0.5041
# Epoch 186/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5009
# Epoch 186: val_loss did not improve from 0.50197
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 19s 105ms/step - loss: 0.5009 - val_loss: 0.5047
# Epoch 187/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.4999
# Epoch 187: val_loss improved from 0.50197 to 0.50114, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 139ms/step - loss: 0.4999 - val_loss: 0.5011
# Epoch 188/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.5017
# Epoch 188: val_loss did not improve from 0.50114
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5017 - val_loss: 0.5064
# Epoch 189/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5023
# Epoch 189: val_loss did not improve from 0.50114
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 26s 136ms/step - loss: 0.5023 - val_loss: 0.5013
# Epoch 190/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5027
# Epoch 190: val_loss did not improve from 0.50114
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5027 - val_loss: 0.5063
# Epoch 191/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5001
# Epoch 191: val_loss improved from 0.50114 to 0.50041, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 142ms/step - loss: 0.5001 - val_loss: 0.5004
# Epoch 192/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5001
# Epoch 192: val_loss did not improve from 0.50041
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.5001 - val_loss: 0.5054
# Epoch 193/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.4993
# Epoch 193: val_loss did not improve from 0.50041
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 136ms/step - loss: 0.4993 - val_loss: 0.5015
# Epoch 194/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.4993
# Epoch 194: val_loss did not improve from 0.50041
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.4993 - val_loss: 0.5060
# Epoch 195/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.4998
# Epoch 195: val_loss did not improve from 0.50041
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 137ms/step - loss: 0.4998 - val_loss: 0.5017
# Epoch 196/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.4981
# Epoch 196: val_loss did not improve from 0.50041
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.4981 - val_loss: 0.5044
# Epoch 197/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5006
# Epoch 197: val_loss improved from 0.50041 to 0.49943, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - loss: 0.5006 - val_loss: 0.4994
# Epoch 198/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.4991
# Epoch 198: val_loss did not improve from 0.49943
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.4991 - val_loss: 0.5038
# Epoch 199/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.4995
# Epoch 199: val_loss did not improve from 0.49943
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 135ms/step - loss: 0.4995 - val_loss: 0.5008
# Epoch 200/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.4995
# Epoch 200: val_loss did not improve from 0.49943
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 0.4995 - val_loss: 0.5023

# %% [markdown]
# ## Validation try

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
# Function to load a single image and mask
def load_single_image(img_path, mask_path, target_size):
    # Load and preprocess the image
    img = np.asarray(image.load_img(
        img_path,
        target_size=(target_size, target_size, 3))
    )
    
    # Load and preprocess the mask
    img_mask = image.load_img(
        mask_path,
        target_size=(target_size, target_size))
    
    img_mask = np.asarray(img_mask).astype('int32')
    
    return img, img_mask

# Select a sample from the validation set
sample_index = 0
sample_img_name = val_list[sample_index]
sample_mask_name = val_list[sample_index]  # Assuming mask filenames are the same as image filenames

sample_img_path = os.path.join(val_data_path, sample_img_name)
sample_mask_path = os.path.join(val_mask_path, sample_mask_name)

# Load the image and mask
input_size = 224  # Ensure this matches your model's expected input size
img, mask = load_single_image(sample_img_path, sample_mask_path, input_size)
img_input = np.expand_dims(img, axis=0)  # Add batch dimension

# Predict
predictions = my_model.predict(img_input)
final_output = predictions[-1][0]  # Extract the first sample from the batch

# Since the model outputs softmax probabilities over 3 classes, take the argmax to get predicted class labels
predicted_mask = np.argmax(final_output, axis=-1)

# Visualization
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(img/255.0)
plt.title('Input Image')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(mask, cmap='gray')
plt.title('Ground Truth Mask')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(predicted_mask)
plt.title('Predicted Mask')
plt.axis('off')

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step

# %%
import os
import numpy as np
from keras.preprocessing import image
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Function to load a single image and mask
def load_single_image(img_path, mask_path, target_size):
    # Load and preprocess the image
    img = np.asarray(image.load_img(
        img_path,
        target_size=(target_size, target_size, 3))
    ).astype('float32')

    # Load and preprocess the mask
    img_mask = image.load_img(
        mask_path,
        target_size=(target_size, target_size),
        color_mode='grayscale')

    img_mask = np.asarray(img_mask).astype('int32')

    return img, img_mask

# Function to remap mask values to discrete classes {0, 1, 2}
def remap_mask_values(mask):
    value_mapping = {
        0: 2,    # Background
        76: 0,   # Disc
        225: 1,
        226: 1   # Cup
    }
    
    # Default value for undefined keys
    default_value = 0  # Treat unexpected values as background if not found
    remapped_mask = np.vectorize(lambda x: value_mapping.get(x, default_value))(mask)
    
    return remapped_mask

# Function to calculate confusion matrix components for a given class
def calculate_class_confusion(predicted_mask, ground_truth_mask, target_class):
    # Flatten the arrays for comparison
    pred_flat = (predicted_mask == target_class).flatten().astype(int)
    gt_flat = (ground_truth_mask == target_class).flatten().astype(int)
    
    # Calculate confusion matrix components
    TP = np.sum((pred_flat == 1) & (gt_flat == 1))  # True Positives
    TN = np.sum((pred_flat == 0) & (gt_flat == 0))  # True Negatives
    FP = np.sum((pred_flat == 1) & (gt_flat == 0))  # False Positives
    FN = np.sum((pred_flat == 0) & (gt_flat == 1))  # False Negatives

    return TP, TN, FP, FN

# Function to calculate metrics given accumulated confusion components
def compute_metrics_from_confusion(TP, TN, FP, FN):
    # Sensitivity (Sen) and Specificity (Spe)
    Sen = TP / (TP + FN) if (TP + FN) > 0 else 0
    Spe = TN / (TN + FP) if (TN + FP) > 0 else 0

    # Overlap metrics
    intersection = TP  # intersection is basically TP for the binary class scenario
    union = TP + FP + FN
    E = 1 - (intersection / union) if union > 0 else 1  # Error
    A = 0.5 * (Sen + Spe)  # Balanced accuracy

    return Sen, Spe, E, A

# Calculate metrics over the whole validation set
def calculate_metrics_over_validation(val_list, val_data_path, val_mask_path, model, input_size=224):
    # Classes: 0 (Disc), 1 (Cup), 2 (Background)
    # We'll accumulate TP, TN, FP, FN for each class
    # For clarity, let's define indices as: 0->Disc, 1->Cup, 2->Background.
    
    class_labels = [0, 1, 2]
    
    # Initialize accumulators
    class_accumulators = {
        cls: {"TP": 0, "TN": 0, "FP": 0, "FN": 0}
        for cls in class_labels
    }
    
    # Iterate over the entire validation set
    for i, img_name in enumerate(val_list):
        mask_name = img_name  # Assuming same filename for mask
        sample_img_path = os.path.join(val_data_path, img_name)
        sample_mask_path = os.path.join(val_mask_path, mask_name)
        
        # Load the image and mask
        img, mask = load_single_image(sample_img_path, sample_mask_path, input_size)
        img_input = np.expand_dims(img, axis=0)  # Add batch dimension

        # Predict
        predictions = model.predict(img_input)
        final_output = predictions[-1][0]  # Extract the first sample's output
        predicted_mask = np.argmax(final_output, axis=-1)

        # Remap ground truth mask values if necessary
        ground_truth_mask = remap_mask_values(mask)

        # Accumulate confusion values for each class
        for cls in class_labels:
            TP, TN, FP, FN = calculate_class_confusion(predicted_mask, ground_truth_mask, cls)
            class_accumulators[cls]["TP"] += TP
            class_accumulators[cls]["TN"] += TN
            class_accumulators[cls]["FP"] += FP
            class_accumulators[cls]["FN"] += FN

    # After processing the whole dataset, compute the final metrics
    final_metrics = {}
    for cls in class_labels:
        TP = class_accumulators[cls]["TP"]
        TN = class_accumulators[cls]["TN"]
        FP = class_accumulators[cls]["FP"]
        FN = class_accumulators[cls]["FN"]

        Sen, Spe, E, A = compute_metrics_from_confusion(TP, TN, FP, FN)
        final_metrics[f"Class {cls}"] = {
            "Sensitivity (Sen)": Sen,
            "Specificity (Spe)": Spe,
            "Error (E)": E,
            "Balanced Accuracy (A)": A,
            "TP": TP,
            "TN": TN,
            "FP": FP,
            "FN": FN
        }

    return final_metrics

# Example usage:
all_metrics = calculate_metrics_over_validation(val_list, val_data_path, val_mask_path, my_model, input_size=224)
for cls, metrics in all_metrics.items():
     print(f"\nMetrics for {cls}:")
     for key, value in metrics.items():
         print(f"{key}: {value:.4f}" if isinstance(value, float) else f"{key}: {value}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Metrics for Class 0:
# Sensitivity (Sen): 0.9443
# Specificity (Spe): 0.8863
# Error (E): 0.2802
# Balanced Accuracy (A): 0.9153
# TP: 3798876
# TN: 9775379
# FP: 1254428
# FN: 224117
#
# Metrics for Class 1:
# Sensitivity (Sen): 0.8200
# Specificity (Spe): 0.9929
# Error (E): 0.1942
# Balanced Accuracy (A): 0.9065
# TP: 3532161
# TN: 10669143
# FP: 76028
# FN: 775468
#
# Metrics for Class 2:
# Sensitivity (Sen): 0.9191
# Specificity (Spe): 0.9744
# Error (E): 0.1091
# Balanced Accuracy (A): 0.9468
# TP: 6178389
# TN: 8117704
# FP: 212918
# FN: 543789

# %%
import os
import numpy as np
from keras.preprocessing import image
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Adjust these based on your setup
num_classes = 3  # e.g., Background=2, Disc=0, Cup=1
class_labels = [0, 1, 2]
input_size = 224

# Function to accumulate predictions and ground truths over the entire validation set
def accumulate_predictions(val_list, val_data_path, val_mask_path, model, input_size=224):
    # We'll store all predictions and ground truths for all pixels across the val set.
    # Each pixel is considered a sample.
    all_probs = []  # Will hold probabilities of shape (N, num_classes) where N is total number of pixels over val set
    all_gt = []     # Will hold ground truth class labels (N,)

    for img_name in val_list:
        mask_name = img_name  # Assuming same filename for mask
        img_path = os.path.join(val_data_path, img_name)
        mask_path = os.path.join(val_mask_path, mask_name)

        # Load the image and mask
        img, mask = load_single_image(img_path, mask_path, input_size)
        img_input = np.expand_dims(img, axis=0)

        # Predict probabilities
        # 'model.predict' should return a list if it's a multi-output model;
        # if your model returns a single output (probabilities), just adjust accordingly.
        predictions = model.predict(img_input)
        # final_output should be the last layer's output (N=1, H, W, C)
        # Here we assume predictions[-1] gives us the desired output if it's a multi-output model.
        final_output = predictions[-1][0]  # shape: (input_size, input_size, num_classes)

        ground_truth_mask = remap_mask_values(mask)  # shape: (input_size, input_size)

        # Flatten the arrays
        flat_probs = final_output.reshape(-1, num_classes)  # shape: (input_size*input_size, num_classes)
        flat_gt = ground_truth_mask.flatten()               # shape: (input_size*input_size, )

        # Accumulate
        all_probs.append(flat_probs)
        all_gt.append(flat_gt)

    # Concatenate all
    all_probs = np.concatenate(all_probs, axis=0)  # shape: (Total_pixels_in_val_set, num_classes)
    all_gt = np.concatenate(all_gt, axis=0)        # shape: (Total_pixels_in_val_set, )

    return all_probs, all_gt

def plot_roc_auc(all_probs, all_gt, class_labels):
    plt.figure(figsize=(8,6))
    # Compute ROC and AUC for each class in a one-vs-rest manner
    for cls in class_labels:
        # Binary ground truth for this class
        binary_gt = (all_gt == cls).astype(int)

        # Predicted probability for this class
        cls_probs = all_probs[:, cls]  # Probability of class 'cls'

        # Compute ROC curve
        fpr, tpr, thresholds = roc_curve(binary_gt, cls_probs)
        roc_auc = auc(fpr, tpr)
        print(roc_auc)

        plt.plot(fpr, tpr, label=f'Class {cls} (AUC = {roc_auc:.2f})')

    # Plot random guess line
    plt.plot([0,1], [0,1], 'k--', label='Random Guess')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate', fontsize=14)
    plt.ylabel('True Positive Rate', fontsize=14)
    plt.title('ROC Curves', fontsize=16)
    plt.legend(loc="lower right")
    plt.show()

# Example usage:
all_probs, all_gt = accumulate_predictions(val_list, val_data_path, val_mask_path, my_model, input_size=224)
plot_roc_auc(all_probs, all_gt, class_labels=[0,1,2])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 0.9697382222528158
# 0.9683476478587802
# 0.9848291879692925

# %%
import os
import numpy as np
from keras.preprocessing import image
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical

# Adjust these based on your setup
num_classes = 3  # e.g., 0=Disc, 1=Cup, 2=Background
input_size = 224

def plot_micro_average_roc(all_probs, all_gt, num_classes):
    # One-hot encode the ground truth for micro-average calculation
    all_gt_one_hot = to_categorical(all_gt, num_classes=num_classes)

    # Flatten arrays into a single binary classification problem (micro-average)
    y_true = all_gt_one_hot.ravel()
    y_score = all_probs.ravel()

    # Compute ROC curve and AUC for the micro-average
    fpr, tpr, _ = roc_curve(y_true, y_score)
    roc_auc = auc(fpr, tpr)

    # Print the AUC value
    print(f"Micro-average AUC: {roc_auc:.4f}")

    # Plot the ROC curve
    plt.figure(figsize=(8,6))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='Model (AUC = {:.3f})'.format(roc_auc))
    plt.plot([0,1],[0,1],'k--', lw=2, label='Random Guess')
    plt.xlim([0.0,1.0])
    plt.ylim([0.0,1.05])
    plt.xlabel('False Positive Rate', fontsize=14)
    plt.ylabel('True Positive Rate', fontsize=14)
    plt.title('Receiver Operating Characteristic', fontsize=16)
    plt.legend(loc="lower right")
    plt.show()

# Example usage:
# Make sure val_list, val_data_path, val_mask_path, and my_model are defined.
all_probs, all_gt = accumulate_predictions(val_list, val_data_path, val_mask_path, my_model, input_size=input_size)
plot_micro_average_roc(all_probs, all_gt, num_classes=num_classes)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
